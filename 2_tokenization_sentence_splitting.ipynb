# %%
import spacy
import medspacy

# %%
with open("./texto_historia_v2.txt") as f:
    text = f.read()

# %%
nlp = spacy.blank("es")
nlp.pipe_names
# Out:
# []

# %% [markdown]
# Tokenization

# %%
from medspacy.custom_tokenizer import create_medspacy_tokenizer

# %%
medspacy_tokenizer = create_medspacy_tokenizer(nlp)
default_tokenizer = nlp.tokenizer

# %%
example_text = r'Pt c\o n;v;d h\o chf+cp'

# %%
print("Tokens from default tokenizer:")
print(list(default_tokenizer(example_text)))
print()
print("Tokens from medspacy tokenizer:")
print(list(medspacy_tokenizer(example_text)))
# Out:
# Tokens from default tokenizer:
# [Pt, c\o, n;v;d, h\o, chf+cp]
#
# Tokens from medspacy tokenizer:
# [Pt, c, \, o, n, ;, v, ;, d, h, \, o, chf, +, cp]

# %%
nlp.tokenizer = medspacy_tokenizer
print(list(nlp(example_text)))
# Out:
# [Pt, c, \, o, n, ;, v, ;, d, h, \, o, chf, +, cp]

# %% [markdown]
# Segmentacion de oraciones

# %%
#PyRush es un algoritmo de segmentación de oraciones diseñado para manejar el lenguaje médico, 
# que a menudo contiene abreviaturas, símbolos y estructuras de oración complejas. 
# PyRuSH es una implementación en Python de este algoritmo, que se integra fácilmente con spaCy y 
# medspacy para mejorar la precisión de la segmentación de oraciones en textos médicos.
from medspacy.sentence_splitting import PyRuSHSentencizer

# %%
nlp.add_pipe("medspacy_pyrush")

# %%
nlp.pipe_names
# Out:
# ['medspacy_pyrush']

# %%
doc = nlp(text)
# Out:
# 2026-03-17 09:52:20.077 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 0 'Fecha' marked as sentence start (span begin)
# 2026-03-17 09:52:20.078 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 23 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.079 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 23-23 (idx 69-69) between spans 69-71
# 2026-03-17 09:52:20.080 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 23 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.080 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 24 'Fecha' marked as sentence start (span begin)
# 2026-03-17 09:52:20.081 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 39 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.082 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 39-39 (idx 122-122) between spans 122-124
# 2026-03-17 09:52:20.082 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 39 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.083 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 40 'Servicio' marked as sentence start (span begin)
# 2026-03-17 09:52:20.084 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 43 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.084 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 43-43 (idx 141-141) between spans 141-143
# 2026-03-17 09:52:20.085 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 43 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.085 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 44 'Alergias' marked as sentence start (span begin)
# 2026-03-17 09:52:20.086 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 46 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.086 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 46-46 (idx 152-152) between spans 152-153
# 2026-03-17 09:52:20.086 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 46 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.087 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 47 'Hidroclorotiazida' marked as sentence start (span begin)
# 2026-03-17 09:52:20.087 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 48 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.088 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 48-48 (idx 170-170) between spans 170-172
# 2026-03-17 09:52:20.088 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 48 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.089 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 49 'Médico' marked as sentence start (span begin)
# 2026-03-17 09:52:20.090 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 64 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.091 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 64-64 (idx 228-228) between spans 228-229
# 2026-03-17 09:52:20.095 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 64 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.095 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 65 'Dolor' marked as sentence start (span begin)
# 2026-03-17 09:52:20.096 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 67 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.097 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 67-67 (idx 244-244) between spans 244-246
# 2026-03-17 09:52:20.098 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 67 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.099 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 68 'Procedimiento' marked as sentence start (span begin)
# 2026-03-17 09:52:20.099 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 74 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.100 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 74-74 (idx 288-288) between spans 288-289
# 2026-03-17 09:52:20.101 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 74 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.101 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 75 'Línea' marked as sentence start (span begin)
# 2026-03-17 09:52:20.102 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 91 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.103 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 91-91 (idx 337-337) between spans 337-339
# 2026-03-17 09:52:20.103 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 91 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.104 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 92 'Historia' marked as sentence start (span begin)
# 2026-03-17 09:52:20.105 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 98 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.106 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 98-98 (idx 372-372) between spans 372-373
# 2026-03-17 09:52:20.107 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 98 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.107 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 99 'Mujer' marked as sentence start (span begin)
# 2026-03-17 09:52:20.108 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 129 'Las' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.109 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 129 'Las' marked as sentence start (span begin)
# 2026-03-17 09:52:20.109 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 137 'No' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.110 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 137 'No' marked as sentence start (span begin)
# 2026-03-17 09:52:20.111 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 142 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.113 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 142-142 (idx 600-600) between spans 600-602
# 2026-03-17 09:52:20.114 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 142 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.115 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 143 'Antecedentes' marked as sentence start (span begin)
# 2026-03-17 09:52:20.116 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 146 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.117 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 146-146 (idx 623-623) between spans 623-625
# 2026-03-17 09:52:20.117 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 146 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.118 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 147 'Cáncer' marked as sentence start (span begin)
# 2026-03-17 09:52:20.118 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 167 'Última' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.120 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 167 'Última' marked as sentence start (span begin)
# 2026-03-17 09:52:20.122 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 175 'El' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.123 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 175 'El' marked as sentence start (span begin)
# 2026-03-17 09:52:20.123 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 190 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.124 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 190-190 (idx 823-823) between spans 823-825
# 2026-03-17 09:52:20.124 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 190 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.125 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 191 'Diabetes' marked as sentence start (span begin)
# 2026-03-17 09:52:20.125 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 195 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.127 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 195-195 (idx 850-850) between spans 850-852
# 2026-03-17 09:52:20.128 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 195 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.128 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 196 'Hipertensión' marked as sentence start (span begin)
# 2026-03-17 09:52:20.129 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 197 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.131 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 197-197 (idx 864-864) between spans 864-866
# 2026-03-17 09:52:20.132 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 197 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.133 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 198 'Historia' marked as sentence start (span begin)
# 2026-03-17 09:52:20.134 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 201 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.135 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 201-201 (idx 882-882) between spans 882-883
# 2026-03-17 09:52:20.135 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 201 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.136 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 202 'Casada' marked as sentence start (span begin)
# 2026-03-17 09:52:20.138 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 209 'Sin' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.139 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 209 'Sin' marked as sentence start (span begin)
# 2026-03-17 09:52:20.140 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 216 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.140 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 216-216 (idx 949-949) between spans 949-951
# 2026-03-17 09:52:20.141 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 216 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.142 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 217 'Historia' marked as sentence start (span begin)
# 2026-03-17 09:52:20.142 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 220 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.144 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 220-220 (idx 969-969) between spans 969-970
# 2026-03-17 09:52:20.144 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 220 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.145 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 221 'Madre' marked as sentence start (span begin)
# 2026-03-17 09:52:20.146 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 231 'Sin' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.146 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 231 'Sin' marked as sentence start (span begin)
# 2026-03-17 09:52:20.147 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 235 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.149 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 235-235 (idx 1029-1029) between spans 1029-1030
# 2026-03-17 09:52:20.150 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 235 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.150 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 236 '2' marked as sentence start (span begin)
# 2026-03-17 09:52:20.151 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 241 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.152 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 241-241 (idx 1046-1046) between spans 1046-1048
# 2026-03-17 09:52:20.153 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 241 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.153 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 242 'Resumen' marked as sentence start (span begin)
# 2026-03-17 09:52:20.154 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 247 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.155 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 247-247 (idx 1079-1079) between spans 1079-1080
# 2026-03-17 09:52:20.155 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 247 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.156 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 248 'La' marked as sentence start (span begin)
# 2026-03-17 09:52:20.157 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 284 'Fue' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.159 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 284 'Fue' marked as sentence start (span begin)
# 2026-03-17 09:52:20.161 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 296 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.162 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 296-296 (idx 1315-1315) between spans 1315-1317
# 2026-03-17 09:52:20.162 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 296 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.163 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 297 'Medicamentos' marked as sentence start (span begin)
# 2026-03-17 09:52:20.164 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 301 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.165 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 301-301 (idx 1338-1338) between spans 1338-1340
# 2026-03-17 09:52:20.166 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 301 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.169 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 302 'Nitrato' marked as sentence start (span begin)
# 2026-03-17 09:52:20.171 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 308 'Sig' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.173 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 308 'Sig' marked as sentence start (span begin)
# 2026-03-17 09:52:20.174 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 327 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.175 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 327-327 (idx 1443-1443) between spans 1443-1445
# 2026-03-17 09:52:20.175 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 327 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.176 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 328 'Heparina' marked as sentence start (span begin)
# 2026-03-17 09:52:20.177 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 340 'Sig' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.177 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 340 'Sig' marked as sentence start (span begin)
# 2026-03-17 09:52:20.178 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 355 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.179 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 355-355 (idx 1542-1542) between spans 1542-1544
# 2026-03-17 09:52:20.179 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 355 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.180 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 356 'Acetaminofén' marked as sentence start (span begin)
# 2026-03-17 09:52:20.181 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 363 'Sig' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.182 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 363 'Sig' marked as sentence start (span begin)
# 2026-03-17 09:52:20.182 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 384 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.183 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 384-384 (idx 1635-1635) between spans 1635-1637
# 2026-03-17 09:52:20.183 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 384 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.184 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 385 'Diagnóstico' marked as sentence start (span begin)
# 2026-03-17 09:52:20.186 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 389 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.187 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 389-389 (idx 1657-1657) between spans 1657-1658
# 2026-03-17 09:52:20.190 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 389 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.191 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 390 'DM' marked as sentence start (span begin)
# 2026-03-17 09:52:20.193 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 395 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.194 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 395-395 (idx 1680-1680) between spans 1680-1681
# 2026-03-17 09:52:20.195 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 395 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.195 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 396 'HTA' marked as sentence start (span begin)
# 2026-03-17 09:52:20.196 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 404 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.197 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 404-404 (idx 1738-1738) between spans 1738-1740
# 2026-03-17 09:52:20.198 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 404 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.199 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 405 'Instrucciones' marked as sentence start (span begin)
# 2026-03-17 09:52:20.199 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 409 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.200 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 409-409 (idx 1762-1762) between spans 1762-1763
# 2026-03-17 09:52:20.206 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 409 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.210 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 410 'La' marked as sentence start (span begin)
# 2026-03-17 09:52:20.211 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 415 'Por' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.211 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 415 'Por' marked as sentence start (span begin)
# 2026-03-17 09:52:20.212 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 460 '
#
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.213 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 460-460 (idx 2021-2021) between spans 2021-2023
# 2026-03-17 09:52:20.213 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 460 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.214 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 461 'Completado' marked as sentence start (span begin)
# 2026-03-17 09:52:20.217 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 496 '[' marked as sentence start (span end next token)
# 2026-03-17 09:52:20.218 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 496 '[' marked as sentence start (span begin)
# 2026-03-17 09:52:20.219 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 502 '
# ' marked as sentence start (span end whitespace)
# 2026-03-17 09:52:20.219 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 502-502 (idx 2164-2164) between spans 2164-2165
# 2026-03-17 09:52:20.220 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 502 '
# ' marked as sentence start (whitespace in gap between spans)
# 2026-03-17 09:52:20.220 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 503 'el' marked as sentence start (span begin)
# 2026-03-17 09:52:20.221 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] Token/tag mapping: [(Fecha, True), (de, False), (Admisión, False), (:, False), ([, False), (2573, False), (-, False), (5, False), (-, False), (30, False), (], False), (             , False), (Fecha, False), (de, False), (Alta, False), (:, False), ([, False), (2573, False), (-, False), (7, False), (-, False), (1, False), (], False), (
#
# , True), (Fecha, True), (de, False), (Nacimiento, False), (:, False), ([, False), (2498, False), (-, False), (8, False), (-, False), (19, False), (], False), (           , False), (Sexo, False), (:, False), (F, False), (
#
# , True), (Servicio, True), (:, False), (CIRUGÍA, False), (
#
# , True), (Alergias, True), (:, False), (
# , True), (Hidroclorotiazida, True), (
#
# , True), (Médico, True), (Tratante, False), (:, False), ([, False), (Nombre1, False), ((, False), (LF, False), (), False), (1893, False), (], False), (
# , False), (Motivo, False), (de, False), (Consulta, False), (:, False), (
# , True), (Dolor, True), (abdominal, False), (
#
# , True), (Procedimiento, True), (Quirúrgico, False), (o, False), (Invasivo, False), (Mayor, False), (:, False), (
# , True), (Línea, True), (PICC, False), ([, False), (6, False), (-, False), (25, False), (], False), (
# , False), (CPRE, False), (con, False), (esfinterotomía, False), ([, False), (5, False), (-, False), (31, False), (], False), (
#
# , True), (Historia, True), (de, False), (la, False), (Enfermedad, False), (Actual, False), (:, False), (
# , True), (Mujer, True), (de, False), (74, False), (años, False), (con, False), (DM, False), (tipo, False), (2, False), (y, False), (accidente, False), (cerebrovascular, False), ((, False), (ACV, False), (), False), (reciente, False), (que, False), (afecta, False), (su, False), (habla, False), (,, False), (quien, False), (se, False), (presenta, False), (con, False), (2, False), (días, False), (de, False), (dolor, False), (abdominal, False), (., False), (Las, True), (imágenes, False), (no, False), (muestran, False), (evidencia, False), (de, False), (metástasis, False), (., False), (No, True), (está, False), (recibiendo, False), (quimioterapia, False), (., False), (
#
# , True), (Antecedentes, True), (Médicos, False), (:, False), (
#
# , True), (Cáncer, True), (de, False), (colon, False), (diagnosticado, False), (en, False), ([, False), (2554, False), (], False), (,, False), (tratado, False), (con, False), (hemicolectomía, False), (,, False), (radioterapia, False), ((, False), (XRT, False), (), False), (y, False), (quimioterapia, False), (., False), (Última, True), (colonoscopia, False), (mostró, False), (:, False), ([, False), (Pendiente, False), (], False), (., False), (El, True), (último, False), (CEA, False), (fue, False), (de, False), (un, False), (rango, False), (de, False), (8, False), ((, False), (disminuyó, False), (de, False), (9, False), (), False), (., False), (
#
# , True), (Diabetes, True), (Mellitus, False), (Tipo, False), (II, False), (
#
# , True), (Hipertensión, True), (
#
# , True), (Historia, True), (Social, False), (:, False), (
# , True), (Casada, True), (,, False), (ex, False), (consumidora, False), (de, False), (tabaco, False), (., False), (Sin, True), (consumo, False), (de, False), (alcohol, False), (o, False), (drogas, False), (., False), (
#
# , True), (Historia, True), (Familiar, False), (:, False), (
# , True), (Madre, True), (con, False), (ACV, False), (a, False), (la, False), (edad, False), (de, False), (82, False), (años, False), (., False), (Sin, True), (muertes, False), (prematuras, False), (., False), (
# , True), (2, True), (hijas, False), (-, False), (sanas, False), (., False), (
#
# , True), (Resumen, True), (del, False), (Curso, False), (Hospitalario, False), (:, False), (
# , True), (La, True), (Sra., False), ([, False), (Apellido, False), (del, False), (paciente, False), (2004, False), (], False), (fue, False), (admitida, False), (el, False), ([, False), (2573, False), (-, False), (5, False), (-, False), (30, False), (], False), (., False), (La, False), (ecografía, False), (al, False), (momento, False), (de, False), (la, False), (admisión, False), (demostró, False), (dilatación, False), (del, False), (conducto, False), (pancreático, False), (y, False), (vesícula, False), (biliar, False), (edematosa, False), (., False), (Fue, True), (ingresada, False), (en, False), (la, False), (Unidad, False), (de, False), (Cuidados, False), (Intensivos, False), ((, False), (UCI, False), (), False), (., False), (
#
# , True), (Medicamentos, True), (al, False), (Alta, False), (:, False), (
#
# , True), (Nitrato, True), (de, False), (Miconazol, False), (2, False), (%, False), (Polvo, False), (Sig, True), (:, False), (Una, False), ((, False), (1, False), (), False), (aplicación, False), (tópica, False), (BID, False), ((, False), (2, False), (veces, False), (al, False), (día, False), (), False), (según, False), (sea, False), (necesario, False), (., False), (
#
# , True), (Heparina, True), (Sódica, False), ((, False), (Porcina, False), (), False), (5, False), (,, False), (000, False), (unidades, False), (/, False), (mL, False), (Solución, False), (Sig, True), (:, False), (Una, False), ((, False), (1, False), (), False), (inyección, False), (TID, False), ((, False), (3, False), (veces, False), (al, False), (día, False), (), False), (., False), (
#
# , True), (Acetaminofén, True), (160, False), (mg, False), (/, False), (5, False), (mL, False), (Elixir, False), (Sig, True), (:, False), (Uno, False), ((, False), (1, False), (), False), (PO, False), (cada, False), (4, False), (-, False), (6, False), (horas, False), ((, False), (Q4, False), (-, False), (6H, False), (), False), (según, False), (sea, False), (necesario, False), (., False), (
#
# , True), (Diagnóstico, True), (al, False), (Alta, False), (:, False), (
# , True), (DM, True), (Tipo, False), (2, False), (
# , False), (Pancreatitis, False), (
# , True), (HTA, True), (
# , False), (Antecedente, False), (de, False), (dificultad, False), (respiratoria, False), (por, False), (aspiración, False), (
#
# , True), (Instrucciones, True), (al, False), (Alta, False), (:, False), (
# , True), (La, True), (paciente, False), (puede, False), (ducharse, False), (., False), (Por, True), (favor, False), (,, False), (llame, False), (a, False), (su, False), (cirujano, False), (o, False), (regrese, False), (a, False), (la, False), (sala, False), (de, False), (emergencias, False), (si, False), (experimenta, False), (fiebre, False), (mayor, False), (a, False), (38.6, False), (C, False), ((, False), (101.5, False), (F, False), (), False), (,, False), (náuseas, False), (,, False), (vómitos, False), (,, False), (dolor, False), (abdominal, False), (,, False), (dificultad, False), (para, False), (respirar, False), (o, False), (cualquier, False), (cambio, False), (significativo, False), (en, False), (su, False), (condición, False), (médica, False), (., False), (
#
# , True), (Completado, True), (por, False), (:, False), ([, False), (Nombre11, False), (2010, False), (], False), ([, False), (Apellido, False), (2011, False), (], False), (MD, False), ([, False), (Número, False), (MD, False), (2012, False), (], False), ([, False), (2573, False), (-, False), (7, False), (-, False), (1, False), (], False), (@, False), (14, False), (:, False), (04, False), (
# , False), (Firmado, False), (electrónicamente, False), (por, False), (:, False), (DR, False), (., False), ([, True), (Nombre8, False), (], False), ([, False), (Apellido, False), (], False), (
# , True), (el, True), (:, False), (VIE, False), ([, False), (2573, False), (-, False), (7, False), (-, False), (2, False), (], False), (8, False), (:, False), (03, False), (AM, False), (
# , False), ((, False), (Fin, False), (del, False), (Reporte, False), (), False)]

# %%
for sent in doc.sents:
    print(sent)
    print("---"*10)
# Out:
# Fecha de Admisión: [2573-5-30]              Fecha de Alta: [2573-7-1]
# ------------------------------
#
#
#
# ------------------------------
# Fecha de Nacimiento: [2498-8-19]            Sexo: F
# ------------------------------
#
#
#
# ------------------------------
# Servicio: CIRUGÍA
# ------------------------------
#
#
#
# ------------------------------
# Alergias:
# ------------------------------
#
#
# ------------------------------
# Hidroclorotiazida
# ------------------------------
#
#
#
# ------------------------------
# Médico Tratante: [Nombre1 (LF) 1893]
# Motivo de Consulta:
# ------------------------------
#
#
# ------------------------------
# Dolor abdominal
# ------------------------------
#
#
#
# ------------------------------
# Procedimiento Quirúrgico o Invasivo Mayor:
# ------------------------------
#
#
# ------------------------------
# Línea PICC [6-25]
# CPRE con esfinterotomía [5-31]
# ------------------------------
#
#
#
# ------------------------------
# Historia de la Enfermedad Actual:
# ------------------------------
#
#
# ------------------------------
# Mujer de 74 años con DM tipo 2 y accidente cerebrovascular (ACV) reciente que afecta su habla, quien se presenta con 2 días de dolor abdominal.
# ------------------------------
# Las imágenes no muestran evidencia de metástasis.
# ------------------------------
# No está recibiendo quimioterapia.
# ------------------------------
#
#
#
# ------------------------------
# Antecedentes Médicos:
# ------------------------------
#
#
#
# ------------------------------
# Cáncer de colon diagnosticado en [2554], tratado con hemicolectomía, radioterapia (XRT) y quimioterapia.
# ------------------------------
# Última colonoscopia mostró: [Pendiente].
# ------------------------------
# El último CEA fue de un rango de 8 (disminuyó de 9).
# ------------------------------
#
#
#
# ------------------------------
# Diabetes Mellitus Tipo II
# ------------------------------
#
#
#
# ------------------------------
# Hipertensión
# ------------------------------
#
#
#
# ------------------------------
# Historia Social:
# ------------------------------
#
#
# ------------------------------
# Casada, ex consumidora de tabaco.
# ------------------------------
# Sin consumo de alcohol o drogas.
# ------------------------------
#
#
#
# ------------------------------
# Historia Familiar:
# ------------------------------
#
#
# ------------------------------
# Madre con ACV a la edad de 82 años.
# ------------------------------
# Sin muertes prematuras.
# ------------------------------
#
#
# ------------------------------
# 2 hijas - sanas.
# ------------------------------
#
#
#
# ------------------------------
# Resumen del Curso Hospitalario:
# ------------------------------
#
#
# ------------------------------
# La Sra. [Apellido del paciente 2004] fue admitida el [2573-5-30]. La ecografía al momento de la admisión demostró dilatación del conducto pancreático y vesícula biliar edematosa.
# ------------------------------
# Fue ingresada en la Unidad de Cuidados Intensivos (UCI).
# ------------------------------
#
#
#
# ------------------------------
# Medicamentos al Alta:
# ------------------------------
#
#
#
# ------------------------------
# Nitrato de Miconazol 2 % Polvo
# ------------------------------
# Sig: Una (1) aplicación tópica BID (2 veces al día) según sea necesario.
# ------------------------------
#
#
#
# ------------------------------
# Heparina Sódica (Porcina) 5,000 unidades/mL Solución
# ------------------------------
# Sig: Una (1) inyección TID (3 veces al día).
# ------------------------------
#
#
#
# ------------------------------
# Acetaminofén 160 mg/5 mL Elixir
# ------------------------------
# Sig: Uno (1) PO cada 4-6 horas (Q4-6H) según sea necesario.
# ------------------------------
#
#
#
# ------------------------------
# Diagnóstico al Alta:
# ------------------------------
#
#
# ------------------------------
# DM Tipo 2
# Pancreatitis
# ------------------------------
#
#
# ------------------------------
# HTA
# Antecedente de dificultad respiratoria por aspiración
# ------------------------------
#
#
#
# ------------------------------
# Instrucciones al Alta:
# ------------------------------
#
#
# ------------------------------
# La paciente puede ducharse.
# ------------------------------
# Por favor, llame a su cirujano o regrese a la sala de emergencias si experimenta fiebre mayor a 38.6 C (101.5 F), náuseas, vómitos, dolor abdominal, dificultad para respirar o cualquier cambio significativo en su condición médica.
# ------------------------------
#
#
#
# ------------------------------
# Completado por: [Nombre11 2010] [Apellido 2011] MD [Número MD 2012] [2573-7-1] @ 14:04
# Firmado electrónicamente por: DR.
# ------------------------------
# [Nombre8] [Apellido]
# ------------------------------
#
#
# ------------------------------
# el: VIE [2573-7-2] 8:03 AM
# (Fin del Reporte)
# ------------------------------
